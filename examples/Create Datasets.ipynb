# %% [markdown]
# # Create Training and Validation Dataset
#
# Create datasets without using the DeepD3 training GUI. It builds on the data_preparation module.

# %% [markdown]
# ## Imports

# %%
import imageio.v2 as io
import numpy as np
from pathlib import Path
import tifffile
from datetime import datetime

# DeepD3 imports
from deepd3.data_preparation.structure_data import create_d3data, create_d3set
from deepd3.data_preparation.dummy_stack import dummy_stack
from deepd3.training.utils import set_seed

# %% [markdown]
# ## Define path variables

# %%
data_folder = Path(r"../data/images")
label_folder = Path(r"../data/labels/")

output_d3data = Path("../data/d3data")
output_d3data.mkdir(exist_ok=True)

output_d3set = Path("../data/d3set")
output_d3set.mkdir(exist_ok=True)

# Get all image names
img_filenames = list(data_folder.glob("*.tif"))

today = datetime.now().strftime("%y%m%d")

# %% [markdown]
# Get the resolution values from saved images (assumes square pixels).

# %%
resolutions = np.zeros_like(img_filenames, dtype=float)

for n, path in enumerate(img_filenames):
    
    with tifffile.TiffFile(path) as tif:  
        x_res = tif.pages[0].tags["XResolution"].value
        x_res = x_res[0] / x_res[1] if isinstance(x_res, tuple) else float(x_res)

        resolutions[n] = round(1.0 / x_res, 3)

# %% [markdown]
# ## Create structured d3data
#
# This is to train custom 2D images. By calling dummy_stack, an empty dimension is added as a workaround for the missing z dimension.

# %%
from deepd3.data_preparation.dummy_stack import dummy_stack
for n, img_path in enumerate(img_filenames):

    dendrites_label_path = label_folder / f"{img_path.stem}_dendrites.tif"
    spines_label_path = label_folder / f"{img_path.stem}_spines.tif"

    # Load images
    image = io.imread(img_path)    
    dendrites_label = io.imread(dendrites_label_path)
    spines_label = io.imread(spines_label_path)

    # Normalize and convert image to uint16
    image = image - image.min()
    image = image.astype(np.uint16)

    # Create dummy stacks if images are 2D
    if image.ndim == 2:
        image = dummy_stack(image)
        dendrites_label = dummy_stack(dendrites_label)
        spines_label = dummy_stack(spines_label)

    assert image.shape == dendrites_label.shape == spines_label.shape, \
        "Image and label shapes do not match!"

    resolution = resolutions[n]

    # Save as .d3data
    output_fn = output_d3data / f"{img_path.stem}.d3data"

    if not output_fn.exists():   
        # Create d3data file
        create_d3data(
            img_path,
            image,
            dendrites_label,
            spines_label,
            resolution,
            str(output_fn))
# Out:
# Saved ..\data\d3data\img_0001.d3data with stack shape (1, 276, 1104) and resolution 0.091 µm/px
# Saved ..\data\d3data\img_0002.d3data with stack shape (1, 256, 128) and resolution 0.117 µm/px
# Saved ..\data\d3data\img_0003.d3data with stack shape (1, 130, 130) and resolution 0.19 µm/px
# Saved ..\data\d3data\img_0004.d3data with stack shape (1, 260, 130) and resolution 0.146 µm/px
# Saved ..\data\d3data\img_0005.d3data with stack shape (1, 260, 130) and resolution 0.085 µm/px
# Saved ..\data\d3data\img_0006.d3data with stack shape (1, 390, 130) and resolution 0.077 µm/px
# Saved ..\data\d3data\img_0007.d3data with stack shape (1, 396, 132) and resolution 0.061 µm/px
# Saved ..\data\d3data\img_0008.d3data with stack shape (1, 272, 136) and resolution 0.11 µm/px
# Saved ..\data\d3data\img_0009.d3data with stack shape (1, 408, 136) and resolution 0.066 µm/px
# Saved ..\data\d3data\img_0010.d3data with stack shape (1, 490, 140) and resolution 0.114 µm/px
# Saved ..\data\d3data\img_0011.d3data with stack shape (1, 600, 150) and resolution 0.06 µm/px
# Saved ..\data\d3data\img_0012.d3data with stack shape (1, 310, 156) and resolution 0.058 µm/px
# Saved ..\data\d3data\img_0013.d3data with stack shape (1, 170, 170) and resolution 0.241 µm/px
# Saved ..\data\d3data\img_0014.d3data with stack shape (1, 360, 180) and resolution 0.1 µm/px
# Saved ..\data\d3data\img_0008.d3data with stack shape (1, 272, 136) and resolution 0.11 µm/px
# Saved ..\data\d3data\img_0009.d3data with stack shape (1, 408, 136) and resolution 0.066 µm/px
# Saved ..\data\d3data\img_0010.d3data with stack shape (1, 490, 140) and resolution 0.114 µm/px
# Saved ..\data\d3data\img_0011.d3data with stack shape (1, 600, 150) and resolution 0.06 µm/px
# Saved ..\data\d3data\img_0012.d3data with stack shape (1, 310, 156) and resolution 0.058 µm/px
# Saved ..\data\d3data\img_0013.d3data with stack shape (1, 170, 170) and resolution 0.241 µm/px
# Saved ..\data\d3data\img_0014.d3data with stack shape (1, 360, 180) and resolution 0.1 µm/px
# Saved ..\data\d3data\img_0015.d3data with stack shape (1, 376, 188) and resolution 0.181 µm/px
# Saved ..\data\d3data\img_0016.d3data with stack shape (1, 800, 200) and resolution 0.125 µm/px
# Saved ..\data\d3data\img_0017.d3data with stack shape (1, 708, 202) and resolution 0.089 µm/px
# Saved ..\data\d3data\img_0018.d3data with stack shape (1, 618, 206) and resolution 0.063 µm/px
# Saved ..\data\d3data\img_0019.d3data with stack shape (1, 432, 216) and resolution 0.111 µm/px
# Saved ..\data\d3data\img_0020.d3data with stack shape (1, 750, 250) and resolution 0.06 µm/px
# Saved ..\data\d3data\img_0015.d3data with stack shape (1, 376, 188) and resolution 0.181 µm/px
# Saved ..\data\d3data\img_0016.d3data with stack shape (1, 800, 200) and resolution 0.125 µm/px
# Saved ..\data\d3data\img_0017.d3data with stack shape (1, 708, 202) and resolution 0.089 µm/px
# Saved ..\data\d3data\img_0018.d3data with stack shape (1, 618, 206) and resolution 0.063 µm/px
# Saved ..\data\d3data\img_0019.d3data with stack shape (1, 432, 216) and resolution 0.111 µm/px
# Saved ..\data\d3data\img_0020.d3data with stack shape (1, 750, 250) and resolution 0.06 µm/px
# Saved ..\data\d3data\img_0021.d3data with stack shape (1, 128, 256) and resolution 0.07 µm/px
# Saved ..\data\d3data\img_0022.d3data with stack shape (1, 512, 256) and resolution 0.176 µm/px
# Saved ..\data\d3data\img_0023.d3data with stack shape (1, 512, 256) and resolution 0.098 µm/px
# Saved ..\data\d3data\img_0024.d3data with stack shape (1, 138, 276) and resolution 0.094 µm/px
# Saved ..\data\d3data\img_0025.d3data with stack shape (1, 140, 280) and resolution 0.093 µm/px
# Saved ..\data\d3data\img_0026.d3data with stack shape (1, 150, 300) and resolution 0.087 µm/px
# Saved ..\data\d3data\img_0027.d3data with stack shape (1, 620, 310) and resolution 0.071 µm/px
# Saved ..\data\d3data\img_0021.d3data with stack shape (1, 128, 256) and resolution 0.07 µm/px
# Saved ..\data\d3data\img_0022.d3data with stack shape (1, 512, 256) and resolution 0.176 µm/px
# Saved ..\data\d3data\img_0023.d3data with stack shape (1, 512, 256) and resolution 0.098 µm/px
# Saved ..\data\d3data\img_0024.d3data with stack shape (1, 138, 276) and resolution 0.094 µm/px
# Saved ..\data\d3data\img_0025.d3data with stack shape (1, 140, 280) and resolution 0.093 µm/px
# Saved ..\data\d3data\img_0026.d3data with stack shape (1, 150, 300) and resolution 0.087 µm/px
# Saved ..\data\d3data\img_0027.d3data with stack shape (1, 620, 310) and resolution 0.071 µm/px
# Saved ..\data\d3data\img_0028.d3data with stack shape (1, 164, 328) and resolution 0.098 µm/px
# Saved ..\data\d3data\img_0029.d3data with stack shape (1, 700, 350) and resolution 0.091 µm/px
# Saved ..\data\d3data\img_0030.d3data with stack shape (1, 130, 390) and resolution 0.115 µm/px
# Saved ..\data\d3data\img_0031.d3data with stack shape (1, 300, 510) and resolution 0.167 µm/px
# Saved ..\data\d3data\img_0032.d3data with stack shape (1, 256, 512) and resolution 0.098 µm/px
# Saved ..\data\d3data\img_0033.d3data with stack shape (1, 132, 528) and resolution 0.136 µm/px
# Saved ..\data\d3data\img_0028.d3data with stack shape (1, 164, 328) and resolution 0.098 µm/px
# Saved ..\data\d3data\img_0029.d3data with stack shape (1, 700, 350) and resolution 0.091 µm/px
# Saved ..\data\d3data\img_0030.d3data with stack shape (1, 130, 390) and resolution 0.115 µm/px
# Saved ..\data\d3data\img_0031.d3data with stack shape (1, 300, 510) and resolution 0.167 µm/px
# Saved ..\data\d3data\img_0032.d3data with stack shape (1, 256, 512) and resolution 0.098 µm/px
# Saved ..\data\d3data\img_0033.d3data with stack shape (1, 132, 528) and resolution 0.136 µm/px
# Saved ..\data\d3data\img_0034.d3data with stack shape (1, 164, 656) and resolution 0.122 µm/px
# Saved ..\data\d3data\img_0035.d3data with stack shape (1, 600, 200) and resolution 0.075 µm/px
# Saved ..\data\d3data\img_0036.d3data with stack shape (1, 256, 512) and resolution 0.059 µm/px
# Saved ..\data\d3data\img_0037.d3data with stack shape (1, 600, 300) and resolution 0.04 µm/px
# Saved ..\data\d3data\img_0038.d3data with stack shape (1, 132, 264) and resolution 0.133 µm/px
# Saved ..\data\d3data\img_0039.d3data with stack shape (1, 256, 512) and resolution 0.137 µm/px
# Saved ..\data\d3data\img_0034.d3data with stack shape (1, 164, 656) and resolution 0.122 µm/px
# Saved ..\data\d3data\img_0035.d3data with stack shape (1, 600, 200) and resolution 0.075 µm/px
# Saved ..\data\d3data\img_0036.d3data with stack shape (1, 256, 512) and resolution 0.059 µm/px
# Saved ..\data\d3data\img_0037.d3data with stack shape (1, 600, 300) and resolution 0.04 µm/px
# Saved ..\data\d3data\img_0038.d3data with stack shape (1, 132, 264) and resolution 0.133 µm/px
# Saved ..\data\d3data\img_0039.d3data with stack shape (1, 256, 512) and resolution 0.137 µm/px
# Saved ..\data\d3data\img_0040.d3data with stack shape (1, 630, 210) and resolution 0.038 µm/px
# Saved ..\data\d3data\img_0041.d3data with stack shape (1, 594, 198) and resolution 0.045 µm/px
# Saved ..\data\d3data\img_0042.d3data with stack shape (1, 990, 330) and resolution 0.067 µm/px
# Saved ..\data\d3data\img_0043.d3data with stack shape (1, 600, 200) and resolution 0.1 µm/px
# Saved ..\data\d3data\img_0044.d3data with stack shape (1, 600, 150) and resolution 0.067 µm/px
# Saved ..\data\d3data\img_0045.d3data with stack shape (1, 512, 256) and resolution 0.078 µm/px
# Saved ..\data\d3data\img_0040.d3data with stack shape (1, 630, 210) and resolution 0.038 µm/px
# Saved ..\data\d3data\img_0041.d3data with stack shape (1, 594, 198) and resolution 0.045 µm/px
# Saved ..\data\d3data\img_0042.d3data with stack shape (1, 990, 330) and resolution 0.067 µm/px
# Saved ..\data\d3data\img_0043.d3data with stack shape (1, 600, 200) and resolution 0.1 µm/px
# Saved ..\data\d3data\img_0044.d3data with stack shape (1, 600, 150) and resolution 0.067 µm/px
# Saved ..\data\d3data\img_0045.d3data with stack shape (1, 512, 256) and resolution 0.078 µm/px
# Saved ..\data\d3data\img_0046.d3data with stack shape (1, 512, 256) and resolution 0.035 µm/px
# Saved ..\data\d3data\img_0047.d3data with stack shape (1, 390, 130) and resolution 0.062 µm/px
# Saved ..\data\d3data\img_0048.d3data with stack shape (1, 600, 200) and resolution 0.06 µm/px
# Saved ..\data\d3data\img_0049.d3data with stack shape (1, 600, 200) and resolution 0.06 µm/px
# Saved ..\data\d3data\img_0050.d3data with stack shape (1, 600, 150) and resolution 0.067 µm/px
# Saved ..\data\d3data\img_0046.d3data with stack shape (1, 512, 256) and resolution 0.035 µm/px
# Saved ..\data\d3data\img_0047.d3data with stack shape (1, 390, 130) and resolution 0.062 µm/px
# Saved ..\data\d3data\img_0048.d3data with stack shape (1, 600, 200) and resolution 0.06 µm/px
# Saved ..\data\d3data\img_0049.d3data with stack shape (1, 600, 200) and resolution 0.06 µm/px
# Saved ..\data\d3data\img_0050.d3data with stack shape (1, 600, 150) and resolution 0.067 µm/px

# %% [markdown]
# ## Create training and validation sets

# %% [markdown]
# First let's set a random seed for reproducibility.

# %%
import random
set_seed(41)

# %% [markdown]
# Now let's split in two groups.

# %%
d3data_files = list(output_d3data.glob("*.d3data"))
random.shuffle(d3data_files)

# split index (e.g. 80% train, 20% val)
train_ratio = 0.8
split_idx = int(len(d3data_files) * train_ratio)

train_samples = d3data_files[:split_idx]
val_samples   = d3data_files[split_idx:]

# %% [markdown]
# ## Save sets

# %%
create_d3set(train_samples, str(output_d3set / f"{today}_training_dataset.d3set"))
create_d3set(val_samples, str(output_d3set / f"{today}_validation_dataset.d3set"))
# Out:
# ..\data\d3data\img_0017.d3data ...
# ..\data\d3data\img_0041.d3data ...
# ..\data\d3data\img_0006.d3data ...
# ..\data\d3data\img_0008.d3data ...
# ..\data\d3data\img_0049.d3data ...
# ..\data\d3data\img_0028.d3data ...
# ..\data\d3data\img_0048.d3data ...
# ..\data\d3data\img_0013.d3data ...
# ..\data\d3data\img_0030.d3data ...
# ..\data\d3data\img_0024.d3data ...
# ..\data\d3data\img_0042.d3data ...
# ..\data\d3data\img_0043.d3data ...
# ..\data\d3data\img_0039.d3data ...
# ..\data\d3data\img_0032.d3data ...
# ..\data\d3data\img_0031.d3data ...
# ..\data\d3data\img_0005.d3data ...
# ..\data\d3data\img_0038.d3data ...
# ..\data\d3data\img_0012.d3data ...
# ..\data\d3data\img_0003.d3data ...
# ..\data\d3data\img_0007.d3data ...
# ..\data\d3data\img_0034.d3data ...
# ..\data\d3data\img_0014.d3data ...
# ..\data\d3data\img_0026.d3data ...
# ..\data\d3data\img_0027.d3data ...
# ..\data\d3data\img_0004.d3data ...
# ..\data\d3data\img_0040.d3data ...
# ..\data\d3data\img_0044.d3data ...
# ..\data\d3data\img_0020.d3data ...
# ..\data\d3data\img_0023.d3data ...
# ..\data\d3data\img_0033.d3data ...
# ..\data\d3data\img_0009.d3data ...
# ..\data\d3data\img_0047.d3data ...
# ..\data\d3data\img_0021.d3data ...
# ..\data\d3data\img_0035.d3data ...
# ..\data\d3data\img_0010.d3data ...
# ..\data\d3data\img_0029.d3data ...
# ..\data\d3data\img_0002.d3data ...
# ..\data\d3data\img_0016.d3data ...
# ..\data\d3data\img_0001.d3data ...
# ..\data\d3data\img_0045.d3data ...
# Saved ..\data\d3set\251215_training_dataset.d3set with 40 datasets.
# ..\data\d3data\img_0046.d3data ...
# ..\data\d3data\img_0018.d3data ...
# ..\data\d3data\img_0036.d3data ...
# ..\data\d3data\img_0019.d3data ...
# ..\data\d3data\img_0037.d3data ...
# ..\data\d3data\img_0050.d3data ...
# ..\data\d3data\img_0011.d3data ...
# ..\data\d3data\img_0015.d3data ...
# ..\data\d3data\img_0022.d3data ...
# ..\data\d3data\img_0025.d3data ...
# Saved ..\data\d3set\251215_validation_dataset.d3set with 10 datasets.
# Saved ..\data\d3set\251215_training_dataset.d3set with 40 datasets.
# ..\data\d3data\img_0046.d3data ...
# ..\data\d3data\img_0018.d3data ...
# ..\data\d3data\img_0036.d3data ...
# ..\data\d3data\img_0019.d3data ...
# ..\data\d3data\img_0037.d3data ...
# ..\data\d3data\img_0050.d3data ...
# ..\data\d3data\img_0011.d3data ...
# ..\data\d3data\img_0015.d3data ...
# ..\data\d3data\img_0022.d3data ...
# ..\data\d3data\img_0025.d3data ...
# Saved ..\data\d3set\251215_validation_dataset.d3set with 10 datasets.
# c:\Users\dcupolillo\AppData\Local\anaconda3\envs\2p\lib\site-packages\flammkuchen\hdf5io.py:302: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->Index(['Generated_from', 'Timestamp'], dtype='object')]
#
#   store.put(group._v_pathname + "/" + name, level)
# c:\Users\dcupolillo\AppData\Local\anaconda3\envs\2p\lib\site-packages\flammkuchen\hdf5io.py:302: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->Index(['Generated_from', 'Timestamp'], dtype='object')]
#
#   store.put(group._v_pathname + "/" + name, level)
