# %% [markdown]
# # Train custom DeepD3 model

# %% [markdown]
# ## Imports

# %%
from pathlib import Path
import pandas as pd
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (
    ModelCheckpoint, CSVLogger,
    LearningRateScheduler)
import segmentation_models as sm
import time
from datetime import datetime
from deepd3.model import DeepD3_Model
from deepd3.training.stream import DataGeneratorStream
from deepd3.training.utils import schedule, set_seed
# Out:
# Segmentation Models: using `keras` framework.

# %% [markdown]
# Ensure GPU is detected.

# %%
assert tf.config.list_physical_devices('GPU')
assert tf.test.is_built_with_cuda()

sm.set_framework("tf.keras")
gpus = tf.config.experimental.list_physical_devices('GPU')

# %% [markdown]
# ## Define training-related variables

# %%
set_seed(41)

# Training parameters
batch_size = 32 
filters = 32
learning_rate = 5e-4
epochs = 30
# Out:
# Random seed 41 has been set.

# %% [markdown]
# ## Define path variables

# %%
# today = datetime.now().strftime("%y%m%d")
today = "251215"

# Datasets
d3set_folder = Path(r"../data/d3set")
training_data_path = d3set_folder / f"{today}_training_dataset.d3set"
validation_data_path = d3set_folder / f"{today}_validation_dataset.d3set"

# Model
model_folder = Path(r"../data/models")
model_folder.mkdir(parents=True, exist_ok=True)
model_filename = f"model_{today}.h5"
model_output_path = model_folder / model_filename

# Logger
logger_filename = model_folder / f'model_{today}_logger.csv'

# %%
from deepd3.data_preparation.analyze_labels import suggest_min_content

# Get recommended min_content based on dataset label density
recommended_min_content = suggest_min_content(
    training_data_path,
    patch_size=128,
    num_samples=10000,
    percentile=10
)

recommended_min_content_val = suggest_min_content(
    validation_data_path,
    patch_size=128,
    num_samples=10000,
    percentile=10
)

print(f"Recommended min_content: {recommended_min_content}")
print(f"Recommended min_content (val): {recommended_min_content_val}")
min_content = recommended_min_content
# Out:
# Recommended min_content: 304
# Recommended min_content (val): 294

# %% [markdown]
# ## Load training data
#
# Given mixed resolution during training, set ```target_resolution``` to ```None```.

# %%
# Create data generators for training and validation
dg_training = DataGeneratorStream(
    training_data_path,
    batch_size=batch_size,
    target_resolution=None,
    min_content=min_content)

dg_validation = DataGeneratorStream(
    validation_data_path,
    batch_size=batch_size,
    target_resolution=None,
    min_content=min_content,
    augment=False,
    shuffle=False)

# Sanity check data generators
# X, Y = dg_training[0]
# print(X.shape, Y[0].shape)

# %% [markdown]
# ## Creating model

# %%
# Create a naive DeepD3 model with a given base filter count
model = DeepD3_Model(
    filters=filters,
    input_shape=(None, None, 1))

model.compile(
    Adam(learning_rate=learning_rate),
    [sm.losses.dice_loss, "mse"],
    metrics=['acc', sm.metrics.iou_score])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, None, None,  0           []
#                                  1)]
#
#  enc_layer0_conv1 (Conv2D)      (None, None, None,   288         ['input[0][0]']
#                                 32)
#
#  enc_layer0_conv1_BN (BatchNorm  (None, None, None,   128        ['enc_layer0_conv1[0][0]']
#  alization)                     32)
#
#  enc_layer0_conv1_activation (A  (None, None, None,   0          ['enc_layer0_conv1_BN[0][0]']
#  ctivation)                     32)
#
#  enc_layer0_conv2 (Conv2D)      (None, None, None,   9216        ['enc_layer0_conv1_activation[0][
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, None, None,  0           []
#                                  1)]
#
#  enc_layer0_conv1 (Conv2D)      (None, None, None,   288         ['input[0][0]']
#                                 32)
#
#  enc_layer0_conv1_BN (BatchNorm  (None, None, None,   128        ['enc_layer0_conv1[0][0]']
#  alization)                     32)
#
#  enc_layer0_conv1_activation (A  (None, None, None,   0          ['enc_layer0_conv1_BN[0][0]']
#  ctivation)                     32)
#
#  enc_layer0_conv2 (Conv2D)      (None, None, None,   9216        ['enc_layer0_conv1_activation[0][
#                                 32)                              0]']
#
#  enc_layer0_identity (Conv2D)   (None, None, None,   32          ['input[0][0]']
#                                 32)
#                                 32)                              0]']
#
#  enc_layer0_identity (Conv2D)   (None, None, None,   32          ['input[0][0]']
#                                 32)
#
#  enc_layer0_conv2_BN (BatchNorm  (None, None, None,   128        ['enc_layer0_conv2[0][0]']
#  alization)                     32)
#
#  enc_layer0_conv2_residual_conn  (None, None, None,   0          ['enc_layer0_identity[0][0]',
#  ection (Add)                   32)                               'enc_layer0_conv2_BN[0][0]']
#
#  enc_layer0_conv2_activation (A  (None, None, None,   0          ['enc_layer0_conv2_residual_conne
#  ctivation)                     32)                              ction[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['enc_layer0_conv2_activation[0][
#                                 32)                              0]']
#
#  enc_layer1_conv1 (Conv2D)      (None, None, None,   18432       ['max_pooling2d[0][0]']
#                                 64)
#
#  enc_layer1_conv1_BN (BatchNorm  (None, None, None,   256        ['enc_layer1_conv1[0][0]']
#  alization)                     64)
#
#  enc_layer1_conv1_activation (A  (None, None, None,   0          ['enc_layer1_conv1_BN[0][0]']
#
#  enc_layer0_conv2_BN (BatchNorm  (None, None, None,   128        ['enc_layer0_conv2[0][0]']
#  alization)                     32)
#
#  enc_layer0_conv2_residual_conn  (None, None, None,   0          ['enc_layer0_identity[0][0]',
#  ection (Add)                   32)                               'enc_layer0_conv2_BN[0][0]']
#
#  enc_layer0_conv2_activation (A  (None, None, None,   0          ['enc_layer0_conv2_residual_conne
#  ctivation)                     32)                              ction[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['enc_layer0_conv2_activation[0][
#                                 32)                              0]']
#
#  enc_layer1_conv1 (Conv2D)      (None, None, None,   18432       ['max_pooling2d[0][0]']
#                                 64)
#
#  enc_layer1_conv1_BN (BatchNorm  (None, None, None,   256        ['enc_layer1_conv1[0][0]']
#  alization)                     64)
#
#  enc_layer1_conv1_activation (A  (None, None, None,   0          ['enc_layer1_conv1_BN[0][0]']
#  ctivation)                     64)
#
#  enc_layer1_conv2 (Conv2D)      (None, None, None,   36864       ['enc_layer1_conv1_activation[0][
#  ctivation)                     64)
#
#  enc_layer1_conv2 (Conv2D)      (None, None, None,   36864       ['enc_layer1_conv1_activation[0][
#                                 64)                              0]']
#
#  enc_layer1_identity (Conv2D)   (None, None, None,   2048        ['max_pooling2d[0][0]']
#                                 64)
#
#  enc_layer1_conv2_BN (BatchNorm  (None, None, None,   256        ['enc_layer1_conv2[0][0]']
#  alization)                     64)
#
#  enc_layer1_conv2_residual_conn  (None, None, None,   0          ['enc_layer1_identity[0][0]',
#  ection (Add)                   64)                               'enc_layer1_conv2_BN[0][0]']
#
#  enc_layer1_conv2_activation (A  (None, None, None,   0          ['enc_layer1_conv2_residual_conne
#  ctivation)                     64)                              ction[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['enc_layer1_conv2_activation[0][
#                                 64)                              0]']
#                                 64)                              0]']
#
#  enc_layer1_identity (Conv2D)   (None, None, None,   2048        ['max_pooling2d[0][0]']
#                                 64)
#
#  enc_layer1_conv2_BN (BatchNorm  (None, None, None,   256        ['enc_layer1_conv2[0][0]']
#  alization)                     64)
#
#  enc_layer1_conv2_residual_conn  (None, None, None,   0          ['enc_layer1_identity[0][0]',
#  ection (Add)                   64)                               'enc_layer1_conv2_BN[0][0]']
#
#  enc_layer1_conv2_activation (A  (None, None, None,   0          ['enc_layer1_conv2_residual_conne
#  ctivation)                     64)                              ction[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['enc_layer1_conv2_activation[0][
#                                 64)                              0]']
#
#  enc_layer2_conv1 (Conv2D)      (None, None, None,   73728       ['max_pooling2d_1[0][0]']
#                                 128)
#
#  enc_layer2_conv1_BN (BatchNorm  (None, None, None,   512        ['enc_layer2_conv1[0][0]']
#  alization)                     128)
#
#  enc_layer2_conv1_activation (A  (None, None, None,   0          ['enc_layer2_conv1_BN[0][0]']
#  ctivation)                     128)
#
#  enc_layer2_conv2 (Conv2D)      (None, None, None,   147456      ['enc_layer2_conv1_activation[0][
#
#  enc_layer2_conv1 (Conv2D)      (None, None, None,   73728       ['max_pooling2d_1[0][0]']
#                                 128)
#
#  enc_layer2_conv1_BN (BatchNorm  (None, None, None,   512        ['enc_layer2_conv1[0][0]']
#  alization)                     128)
#
#  enc_layer2_conv1_activation (A  (None, None, None,   0          ['enc_layer2_conv1_BN[0][0]']
#  ctivation)                     128)
#
#  enc_layer2_conv2 (Conv2D)      (None, None, None,   147456      ['enc_layer2_conv1_activation[0][
#                                 128)                             0]']
#
#  enc_layer2_identity (Conv2D)   (None, None, None,   8192        ['max_pooling2d_1[0][0]']
#                                 128)
#
#  enc_layer2_conv2_BN (BatchNorm  (None, None, None,   512        ['enc_layer2_conv2[0][0]']
#  alization)                     128)
#
#  enc_layer2_conv2_residual_conn  (None, None, None,   0          ['enc_layer2_identity[0][0]',
#  ection (Add)                   128)                              'enc_layer2_conv2_BN[0][0]']
#
#  enc_layer2_conv2_activation (A  (None, None, None,   0          ['enc_layer2_conv2_residual_conne
#  ctivation)                     128)                             ction[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['enc_layer2_conv2_activation[0][
#                                 128)                             0]']
#
#                                 128)                             0]']
#
#  enc_layer2_identity (Conv2D)   (None, None, None,   8192        ['max_pooling2d_1[0][0]']
#                                 128)
#
#  enc_layer2_conv2_BN (BatchNorm  (None, None, None,   512        ['enc_layer2_conv2[0][0]']
#  alization)                     128)
#
#  enc_layer2_conv2_residual_conn  (None, None, None,   0          ['enc_layer2_identity[0][0]',
#  ection (Add)                   128)                              'enc_layer2_conv2_BN[0][0]']
#
#  enc_layer2_conv2_activation (A  (None, None, None,   0          ['enc_layer2_conv2_residual_conne
#  ctivation)                     128)                             ction[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['enc_layer2_conv2_activation[0][
#                                 128)                             0]']
#
#  enc_layer3_conv1 (Conv2D)      (None, None, None,   294912      ['max_pooling2d_2[0][0]']
#                                 256)
#
#  enc_layer3_conv1_BN (BatchNorm  (None, None, None,   1024       ['enc_layer3_conv1[0][0]']
#  enc_layer3_conv1 (Conv2D)      (None, None, None,   294912      ['max_pooling2d_2[0][0]']
#                                 256)
#
#  enc_layer3_conv1_BN (BatchNorm  (None, None, None,   1024       ['enc_layer3_conv1[0][0]']
#  alization)                     256)
#
#  enc_layer3_conv1_activation (A  (None, None, None,   0          ['enc_layer3_conv1_BN[0][0]']
#  ctivation)                     256)
#
#  enc_layer3_conv2 (Conv2D)      (None, None, None,   589824      ['enc_layer3_conv1_activation[0][
#                                 256)                             0]']
#
#  enc_layer3_identity (Conv2D)   (None, None, None,   32768       ['max_pooling2d_2[0][0]']
#                                 256)
#
#  enc_layer3_conv2_BN (BatchNorm  (None, None, None,   1024       ['enc_layer3_conv2[0][0]']
#  alization)                     256)
#
#  enc_layer3_conv2_residual_conn  (None, None, None,   0          ['enc_layer3_identity[0][0]',
#  ection (Add)                   256)                              'enc_layer3_conv2_BN[0][0]']
#
#  enc_layer3_conv2_activation (A  (None, None, None,   0          ['enc_layer3_conv2_residual_conne
#  alization)                     256)
#
#  enc_layer3_conv1_activation (A  (None, None, None,   0          ['enc_layer3_conv1_BN[0][0]']
#  ctivation)                     256)
#
#  enc_layer3_conv2 (Conv2D)      (None, None, None,   589824      ['enc_layer3_conv1_activation[0][
#                                 256)                             0]']
#
#  enc_layer3_identity (Conv2D)   (None, None, None,   32768       ['max_pooling2d_2[0][0]']
#                                 256)
#
#  enc_layer3_conv2_BN (BatchNorm  (None, None, None,   1024       ['enc_layer3_conv2[0][0]']
#  alization)                     256)
#
#  enc_layer3_conv2_residual_conn  (None, None, None,   0          ['enc_layer3_identity[0][0]',
#  ection (Add)                   256)                              'enc_layer3_conv2_BN[0][0]']
#
#  enc_layer3_conv2_activation (A  (None, None, None,   0          ['enc_layer3_conv2_residual_conne
#  ctivation)                     256)                             ction[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, None, None,   0          ['enc_layer3_conv2_activation[0][
#                                 256)                             0]']
#
#  ctivation)                     256)                             ction[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, None, None,   0          ['enc_layer3_conv2_activation[0][
#                                 256)                             0]']
#
#  latent_conv (Conv2D)           (None, None, None,   1179648     ['max_pooling2d_3[0][0]']
#                                 512)
#
#  latent_conv_BN (BatchNormaliza  (None, None, None,   2048       ['latent_conv[0][0]']
#  tion)                          512)
#
#  latent_conv_activation (Activa  (None, None, None,   0          ['latent_conv_BN[0][0]']
#  tion)                          512)
#
#  up_sampling2d (UpSampling2D)   (None, None, None,   0           ['latent_conv_activation[0][0]']
#                                 512)
#
#  up_sampling2d_4 (UpSampling2D)  (None, None, None,   0          ['latent_conv_activation[0][0]']
#                                 512)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['up_sampling2d[0][0]',
#                                 768)                              'enc_layer3_conv2_activation[0][
#                                                                  0]']
#
#  concatenate_4 (Concatenate)    (None, None, None,   0           ['up_sampling2d_4[0][0]',
#  latent_conv (Conv2D)           (None, None, None,   1179648     ['max_pooling2d_3[0][0]']
#                                 512)
#
#  latent_conv_BN (BatchNormaliza  (None, None, None,   2048       ['latent_conv[0][0]']
#  tion)                          512)
#
#  latent_conv_activation (Activa  (None, None, None,   0          ['latent_conv_BN[0][0]']
#  tion)                          512)
#
#  up_sampling2d (UpSampling2D)   (None, None, None,   0           ['latent_conv_activation[0][0]']
#                                 512)
#
#  up_sampling2d_4 (UpSampling2D)  (None, None, None,   0          ['latent_conv_activation[0][0]']
#                                 512)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['up_sampling2d[0][0]',
#                                 768)                              'enc_layer3_conv2_activation[0][
#                                                                  0]']
#
#  concatenate_4 (Concatenate)    (None, None, None,   0           ['up_sampling2d_4[0][0]',
#                                 768)                              'enc_layer3_conv2_activation[0][
#                                                                  0]']
#
#  dendrites_dec_layer4_conv1 (Co  (None, None, None,   1769472    ['concatenate[0][0]']
#  nv2D)                          256)
#
#  spines_dec_layer4_conv1 (Conv2  (None, None, None,   1769472    ['concatenate_4[0][0]']
#  D)                             256)
#
#  dendrites_dec_layer4_conv1_BN   (None, None, None,   1024       ['dendrites_dec_layer4_conv1[0][0
#  (BatchNormalization)           256)                             ]']
#
#  spines_dec_layer4_conv1_BN (Ba  (None, None, None,   1024       ['spines_dec_layer4_conv1[0][0]']
#  tchNormalization)              256)
#
#  dendrites_dec_layer4_conv1_act  (None, None, None,   0          ['dendrites_dec_layer4_conv1_BN[0
#  ivation (Activation)           256)                             ][0]']
#
#  spines_dec_layer4_conv1_activa  (None, None, None,   0          ['spines_dec_layer4_conv1_BN[0][0
#  tion (Activation)              256)                             ]']
#
#  dendrites_dec_layer4_conv2 (Co  (None, None, None,   589824     ['dendrites_dec_layer4_conv1_acti
#  nv2D)                          256)                             vation[0][0]']
#
#                                 768)                              'enc_layer3_conv2_activation[0][
#                                                                  0]']
#
#  dendrites_dec_layer4_conv1 (Co  (None, None, None,   1769472    ['concatenate[0][0]']
#  nv2D)                          256)
#
#  spines_dec_layer4_conv1 (Conv2  (None, None, None,   1769472    ['concatenate_4[0][0]']
#  D)                             256)
#
#  dendrites_dec_layer4_conv1_BN   (None, None, None,   1024       ['dendrites_dec_layer4_conv1[0][0
#  (BatchNormalization)           256)                             ]']
#
#  spines_dec_layer4_conv1_BN (Ba  (None, None, None,   1024       ['spines_dec_layer4_conv1[0][0]']
#  tchNormalization)              256)
#
#  dendrites_dec_layer4_conv1_act  (None, None, None,   0          ['dendrites_dec_layer4_conv1_BN[0
#  ivation (Activation)           256)                             ][0]']
#
#  spines_dec_layer4_conv1_activa  (None, None, None,   0          ['spines_dec_layer4_conv1_BN[0][0
#  tion (Activation)              256)                             ]']
#
#  dendrites_dec_layer4_conv2 (Co  (None, None, None,   589824     ['dendrites_dec_layer4_conv1_acti
#  nv2D)                          256)                             vation[0][0]']
#
#  spines_dec_layer4_conv2 (Conv2  (None, None, None,   589824     ['spines_dec_layer4_conv1_activat
#  D)                             256)                             ion[0][0]']
#
#  dendrites_dec_layer4_conv2_BN   (None, None, None,   1024       ['dendrites_dec_layer4_conv2[0][0
#  (BatchNormalization)           256)                             ]']
#
#  spines_dec_layer4_conv2_BN (Ba  (None, None, None,   1024       ['spines_dec_layer4_conv2[0][0]']
#  tchNormalization)              256)
#
#  dendrites_dec_layer4_conv2_act  (None, None, None,   0          ['dendrites_dec_layer4_conv2_BN[0
#  ivation (Activation)           256)                             ][0]']
#
#  spines_dec_layer4_conv2_activa  (None, None, None,   0          ['spines_dec_layer4_conv2_BN[0][0
#  tion (Activation)              256)                             ]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, None, None,   0          ['dendrites_dec_layer4_conv2_acti
#                                 256)                             vation[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, None, None,   0          ['spines_dec_layer4_conv2_activat
#                                 256)                             ion[0][0]']
#
#  spines_dec_layer4_conv2 (Conv2  (None, None, None,   589824     ['spines_dec_layer4_conv1_activat
#  D)                             256)                             ion[0][0]']
#
#  dendrites_dec_layer4_conv2_BN   (None, None, None,   1024       ['dendrites_dec_layer4_conv2[0][0
#  (BatchNormalization)           256)                             ]']
#
#  spines_dec_layer4_conv2_BN (Ba  (None, None, None,   1024       ['spines_dec_layer4_conv2[0][0]']
#  tchNormalization)              256)
#
#  dendrites_dec_layer4_conv2_act  (None, None, None,   0          ['dendrites_dec_layer4_conv2_BN[0
#  ivation (Activation)           256)                             ][0]']
#
#  spines_dec_layer4_conv2_activa  (None, None, None,   0          ['spines_dec_layer4_conv2_BN[0][0
#  tion (Activation)              256)                             ]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, None, None,   0          ['dendrites_dec_layer4_conv2_acti
#                                 256)                             vation[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, None, None,   0          ['spines_dec_layer4_conv2_activat
#                                 256)                             ion[0][0]']
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['up_sampling2d_1[0][0]',
#                                 384)                              'enc_layer2_conv2_activation[0][
#                                                                  0]']
#
#  concatenate_5 (Concatenate)    (None, None, None,   0           ['up_sampling2d_5[0][0]',
#                                 384)                              'enc_layer2_conv2_activation[0][
#                                                                  0]']
#
#  dendrites_dec_layer3_conv1 (Co  (None, None, None,   442368     ['concatenate_1[0][0]']
#  nv2D)                          128)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['up_sampling2d_1[0][0]',
#                                 384)                              'enc_layer2_conv2_activation[0][
#                                                                  0]']
#
#  concatenate_5 (Concatenate)    (None, None, None,   0           ['up_sampling2d_5[0][0]',
#                                 384)                              'enc_layer2_conv2_activation[0][
#                                                                  0]']
#
#  dendrites_dec_layer3_conv1 (Co  (None, None, None,   442368     ['concatenate_1[0][0]']
#  nv2D)                          128)
#
#  spines_dec_layer3_conv1 (Conv2  (None, None, None,   442368     ['concatenate_5[0][0]']
#  D)                             128)
#
#  dendrites_dec_layer3_conv1_BN   (None, None, None,   512        ['dendrites_dec_layer3_conv1[0][0
#  (BatchNormalization)           128)                             ]']
#
#  spines_dec_layer3_conv1 (Conv2  (None, None, None,   442368     ['concatenate_5[0][0]']
#  D)                             128)
#
#  dendrites_dec_layer3_conv1_BN   (None, None, None,   512        ['dendrites_dec_layer3_conv1[0][0
#  (BatchNormalization)           128)                             ]']
#
#  spines_dec_layer3_conv1_BN (Ba  (None, None, None,   512        ['spines_dec_layer3_conv1[0][0]']
#  tchNormalization)              128)
#
#  dendrites_dec_layer3_conv1_act  (None, None, None,   0          ['dendrites_dec_layer3_conv1_BN[0
#  ivation (Activation)           128)                             ][0]']
#
#  spines_dec_layer3_conv1_activa  (None, None, None,   0          ['spines_dec_layer3_conv1_BN[0][0
#  tion (Activation)              128)                             ]']
#
#  dendrites_dec_layer3_conv2 (Co  (None, None, None,   147456     ['dendrites_dec_layer3_conv1_acti
#  nv2D)                          128)                             vation[0][0]']
#
#  spines_dec_layer3_conv2 (Conv2  (None, None, None,   147456     ['spines_dec_layer3_conv1_activat
#  D)                             128)                             ion[0][0]']
#  spines_dec_layer3_conv1_BN (Ba  (None, None, None,   512        ['spines_dec_layer3_conv1[0][0]']
#  tchNormalization)              128)
#
#  dendrites_dec_layer3_conv1_act  (None, None, None,   0          ['dendrites_dec_layer3_conv1_BN[0
#  ivation (Activation)           128)                             ][0]']
#
#  spines_dec_layer3_conv1_activa  (None, None, None,   0          ['spines_dec_layer3_conv1_BN[0][0
#  tion (Activation)              128)                             ]']
#
#  dendrites_dec_layer3_conv2 (Co  (None, None, None,   147456     ['dendrites_dec_layer3_conv1_acti
#  nv2D)                          128)                             vation[0][0]']
#
#  spines_dec_layer3_conv2 (Conv2  (None, None, None,   147456     ['spines_dec_layer3_conv1_activat
#  D)                             128)                             ion[0][0]']
#
#  dendrites_dec_layer3_conv2_BN   (None, None, None,   512        ['dendrites_dec_layer3_conv2[0][0
#  (BatchNormalization)           128)                             ]']
#
#  spines_dec_layer3_conv2_BN (Ba  (None, None, None,   512        ['spines_dec_layer3_conv2[0][0]']
#  tchNormalization)              128)
#
#  dendrites_dec_layer3_conv2_act  (None, None, None,   0          ['dendrites_dec_layer3_conv2_BN[0
#  ivation (Activation)           128)                             ][0]']
#
#  spines_dec_layer3_conv2_activa  (None, None, None,   0          ['spines_dec_layer3_conv2_BN[0][0
#  tion (Activation)              128)                             ]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, None, None,   0          ['dendrites_dec_layer3_conv2_acti
#                                 128)                             vation[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, None, None,   0          ['spines_dec_layer3_conv2_activat
#                                 128)                             ion[0][0]']
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['up_sampling2d_2[0][0]',
#
#  dendrites_dec_layer3_conv2_BN   (None, None, None,   512        ['dendrites_dec_layer3_conv2[0][0
#  (BatchNormalization)           128)                             ]']
#
#  spines_dec_layer3_conv2_BN (Ba  (None, None, None,   512        ['spines_dec_layer3_conv2[0][0]']
#  tchNormalization)              128)
#
#  dendrites_dec_layer3_conv2_act  (None, None, None,   0          ['dendrites_dec_layer3_conv2_BN[0
#  ivation (Activation)           128)                             ][0]']
#
#  spines_dec_layer3_conv2_activa  (None, None, None,   0          ['spines_dec_layer3_conv2_BN[0][0
#  tion (Activation)              128)                             ]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, None, None,   0          ['dendrites_dec_layer3_conv2_acti
#                                 128)                             vation[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, None, None,   0          ['spines_dec_layer3_conv2_activat
#                                 128)                             ion[0][0]']
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['up_sampling2d_2[0][0]',
#                                 192)                              'enc_layer1_conv2_activation[0][
#                                                                  0]']
#
#  concatenate_6 (Concatenate)    (None, None, None,   0           ['up_sampling2d_6[0][0]',
#                                 192)                              'enc_layer1_conv2_activation[0][
#                                                                  0]']
#
#  dendrites_dec_layer2_conv1 (Co  (None, None, None,   110592     ['concatenate_2[0][0]']
#  nv2D)                          64)
#
#  spines_dec_layer2_conv1 (Conv2  (None, None, None,   110592     ['concatenate_6[0][0]']
#  D)                             64)
#
#  dendrites_dec_layer2_conv1_BN   (None, None, None,   256        ['dendrites_dec_layer2_conv1[0][0
#                                 192)                              'enc_layer1_conv2_activation[0][
#                                                                  0]']
#
#  concatenate_6 (Concatenate)    (None, None, None,   0           ['up_sampling2d_6[0][0]',
#                                 192)                              'enc_layer1_conv2_activation[0][
#                                                                  0]']
#
#  dendrites_dec_layer2_conv1 (Co  (None, None, None,   110592     ['concatenate_2[0][0]']
#  nv2D)                          64)
#
# ...
#  spines_dec_layer2_conv2 (Conv2  (None, None, None,   36864      ['spines_dec_layer2_conv1_activat
#  D)                             64)                              ion[0][0]']
#
#  dendrites_dec_layer2_conv2_BN   (None, None, None,   256        ['dendrites_dec_layer2_conv2[0][0
#  (BatchNormalization)           64)                              ]']
#
#  spines_dec_layer2_conv2_BN (Ba  (None, None, None,   256        ['spines_dec_layer2_conv2[0][0]']
#  tchNormalization)              64)
#  (BatchNormalization)           64)                              ]']
#
#  spines_dec_layer2_conv1_BN (Ba  (None, None, None,   256        ['spines_dec_layer2_conv1[0][0]']
#  tchNormalization)              64)
#
#  dendrites_dec_layer2_conv1_act  (None, None, None,   0          ['dendrites_dec_layer2_conv1_BN[0
#  ivation (Activation)           64)                              ][0]']
#
#  spines_dec_layer2_conv1_activa  (None, None, None,   0          ['spines_dec_layer2_conv1_BN[0][0
#  tion (Activation)              64)                              ]']
#
#  dendrites_dec_layer2_conv2 (Co  (None, None, None,   36864      ['dendrites_dec_layer2_conv1_acti
#  nv2D)                          64)                              vation[0][0]']
#
#  spines_dec_layer2_conv2 (Conv2  (None, None, None,   36864      ['spines_dec_layer2_conv1_activat
#  D)                             64)                              ion[0][0]']
#
#  dendrites_dec_layer2_conv2_BN   (None, None, None,   256        ['dendrites_dec_layer2_conv2[0][0
#  (BatchNormalization)           64)                              ]']
#
#  spines_dec_layer2_conv2_BN (Ba  (None, None, None,   256        ['spines_dec_layer2_conv2[0][0]']
#  tchNormalization)              64)
#
#  dendrites_dec_layer2_conv2_act  (None, None, None,   0          ['dendrites_dec_layer2_conv2_BN[0
#  ivation (Activation)           64)                              ][0]']
#
#  spines_dec_layer2_conv2_activa  (None, None, None,   0          ['spines_dec_layer2_conv2_BN[0][0
#  tion (Activation)              64)                              ]']
#
#  dendrites_dec_layer2_conv2_act  (None, None, None,   0          ['dendrites_dec_layer2_conv2_BN[0
#  ivation (Activation)           64)                              ][0]']
#
#  spines_dec_layer2_conv2_activa  (None, None, None,   0          ['spines_dec_layer2_conv2_BN[0][0
#  tion (Activation)              64)                              ]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, None, None,   0          ['dendrites_dec_layer2_conv2_acti
#                                 64)                              vation[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, None, None,   0          ['spines_dec_layer2_conv2_activat
#                                 64)                              ion[0][0]']
#
#  concatenate_3 (Concatenate)    (None, None, None,   0           ['up_sampling2d_3[0][0]',
#                                 96)                               'enc_layer0_conv2_activation[0][
#                                                                  0]']
#
#  concatenate_7 (Concatenate)    (None, None, None,   0           ['up_sampling2d_7[0][0]',
#                                 96)                               'enc_layer0_conv2_activation[0][
#                                                                  0]']
#
#  dendrites_dec_layer1_conv1 (Co  (None, None, None,   27648      ['concatenate_3[0][0]']
#  nv2D)                          32)
#
#  spines_dec_layer1_conv1 (Conv2  (None, None, None,   27648      ['concatenate_7[0][0]']
#  D)                             32)
#
#  dendrites_dec_layer1_conv1_BN   (None, None, None,   128        ['dendrites_dec_layer1_conv1[0][0
#  (BatchNormalization)           32)                              ]']
#
#  spines_dec_layer1_conv1_BN (Ba  (None, None, None,   128        ['spines_dec_layer1_conv1[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, None, None,   0          ['dendrites_dec_layer2_conv2_acti
#                                 64)                              vation[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, None, None,   0          ['spines_dec_layer2_conv2_activat
#                                 64)                              ion[0][0]']
#
#  concatenate_3 (Concatenate)    (None, None, None,   0           ['up_sampling2d_3[0][0]',
#                                 96)                               'enc_layer0_conv2_activation[0][
#                                                                  0]']
#
#  concatenate_7 (Concatenate)    (None, None, None,   0           ['up_sampling2d_7[0][0]',
#                                 96)                               'enc_layer0_conv2_activation[0][
#                                                                  0]']
#
#  dendrites_dec_layer1_conv1 (Co  (None, None, None,   27648      ['concatenate_3[0][0]']
#  nv2D)                          32)
#
#  spines_dec_layer1_conv1 (Conv2  (None, None, None,   27648      ['concatenate_7[0][0]']
#  D)                             32)
#
#  dendrites_dec_layer1_conv1_BN   (None, None, None,   128        ['dendrites_dec_layer1_conv1[0][0
#  (BatchNormalization)           32)                              ]']
#
#  spines_dec_layer1_conv1_BN (Ba  (None, None, None,   128        ['spines_dec_layer1_conv1[0][0]']
#  tchNormalization)              32)
#
#  dendrites_dec_layer1_conv1_act  (None, None, None,   0          ['dendrites_dec_layer1_conv1_BN[0
#  ivation (Activation)           32)                              ][0]']
#
#  spines_dec_layer1_conv1_activa  (None, None, None,   0          ['spines_dec_layer1_conv1_BN[0][0
#  tion (Activation)              32)                              ]']
#
#  dendrites_dec_layer1_conv2 (Co  (None, None, None,   9216       ['dendrites_dec_layer1_conv1_acti
#  nv2D)                          32)                              vation[0][0]']
#
#  tchNormalization)              32)
#
#  dendrites_dec_layer1_conv1_act  (None, None, None,   0          ['dendrites_dec_layer1_conv1_BN[0
#  ivation (Activation)           32)                              ][0]']
#
#  spines_dec_layer1_conv1_activa  (None, None, None,   0          ['spines_dec_layer1_conv1_BN[0][0
#  tion (Activation)              32)                              ]']
#
#  dendrites_dec_layer1_conv2 (Co  (None, None, None,   9216       ['dendrites_dec_layer1_conv1_acti
#  nv2D)                          32)                              vation[0][0]']
#
#  spines_dec_layer1_conv2 (Conv2  (None, None, None,   9216       ['spines_dec_layer1_conv1_activat
#  D)                             32)                              ion[0][0]']
#
#  dendrites_dec_layer1_conv2_BN   (None, None, None,   128        ['dendrites_dec_layer1_conv2[0][0
#  (BatchNormalization)           32)                              ]']
#
#  spines_dec_layer1_conv2_BN (Ba  (None, None, None,   128        ['spines_dec_layer1_conv2[0][0]']
#  tchNormalization)              32)
#
#  dendrites_dec_layer1_conv2_act  (None, None, None,   0          ['dendrites_dec_layer1_conv2_BN[0
#  ivation (Activation)           32)                              ][0]']
#
#  spines_dec_layer1_conv2_activa  (None, None, None,   0          ['spines_dec_layer1_conv2_BN[0][0
#  tion (Activation)              32)                              ]']
#
#  dendrites (Conv2D)             (None, None, None,   33          ['dendrites_dec_layer1_conv2_acti
#                                 1)                               vation[0][0]']
#
#  spines (Conv2D)                (None, None, None,   33          ['spines_dec_layer1_conv2_activat
#                                 1)                               ion[0][0]']
#
# ==================================================================================================
# Total params: 8,673,922
# Trainable params: 8,667,138
# Non-trainable params: 6,784
# __________________________________________________________________________________________________
#  spines_dec_layer1_conv2 (Conv2  (None, None, None,   9216       ['spines_dec_layer1_conv1_activat
#  D)                             32)                              ion[0][0]']
#
#  dendrites_dec_layer1_conv2_BN   (None, None, None,   128        ['dendrites_dec_layer1_conv2[0][0
#  (BatchNormalization)           32)                              ]']
#
#  spines_dec_layer1_conv2_BN (Ba  (None, None, None,   128        ['spines_dec_layer1_conv2[0][0]']
#  tchNormalization)              32)
#
#  dendrites_dec_layer1_conv2_act  (None, None, None,   0          ['dendrites_dec_layer1_conv2_BN[0
#  ivation (Activation)           32)                              ][0]']
#
#  spines_dec_layer1_conv2_activa  (None, None, None,   0          ['spines_dec_layer1_conv2_BN[0][0
#  tion (Activation)              32)                              ]']
#
#  dendrites (Conv2D)             (None, None, None,   33          ['dendrites_dec_layer1_conv2_acti
#                                 1)                               vation[0][0]']
#
#  spines (Conv2D)                (None, None, None,   33          ['spines_dec_layer1_conv2_activat
#                                 1)                               ion[0][0]']
#
# ==================================================================================================
# Total params: 8,673,922
# Trainable params: 8,667,138
# Non-trainable params: 6,784
# __________________________________________________________________________________________________

# %% [markdown]
# Loading some training callbacks, such as adjusting the learning rate across time, saving training progress and intermediate models

# %%
# Save best model automatically during training
mc = ModelCheckpoint(
    model_output_path,
    save_best_only=True)

# Save metrics
csv = CSVLogger(logger_filename)

# Adjust learning rate during training to allow for better convergence
lrs = LearningRateScheduler(schedule)

# %% [markdown]
# ## Train DeepD3 model

# %%
from tqdm.keras import TqdmCallback
start_time = time.time()
print(
    "Training started at: "
    f"{datetime.fromtimestamp(start_time).strftime('%Y-%m-%d %H:%M:%S')}")

# Actually train the network
history = model.fit(
    dg_training,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=dg_validation,
    callbacks=[mc, csv, lrs, TqdmCallback(verbose=1)],
    verbose=0)

end_time = time.time()

print(
    "Training ended at: "
    f"{datetime.fromtimestamp(end_time).strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Total training time: {(end_time - start_time) / 60:.2f} minutes")
# Out:
# Training started at: 2025-12-15 15:07:49
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0429s vs `on_train_batch_end` time: 0.0558s). Check your callbacks.
# Training ended at: 2025-12-15 16:58:58
# Total training time: 111.15 minutes
# Training ended at: 2025-12-15 16:58:58
# Total training time: 111.15 minutes

# %% [markdown]
# ## Save model and logger

# %%
model.save(model_output_path)

history_df = pd.DataFrame(history.history)
history_df.to_csv(logger_filename, index=False)
